# %% [markdown]
# # Problem Statement
#
# Using ML/DL techniques, match similar products from the Flipkart dataset with the Amazon dataset. Once similar products are matched, display the retail price from FK and AMZ side by side. Please explore as many techniques as possible before choosing the final technique. You may either display the final result in single table format OR You may create a simple form where we input the product name and the output of prices of the product from both websites are displayed.

# %%
# Importing Libraries

import pandas as pd

# %%
# Importing CSV files

df_amz= pd.read_csv(r"amz_com-ecommerce_sample.csv",encoding='unicode_escape")
df_flk= pd.read_csv(r"flipkart_com-ecommerce_sample.csv",encoding='unicode_escape")

# %%
df_amz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  int64
#  7   discounted_price         20000 non-null  int64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
df_amz.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
# finding null values in Amazon Dataset
df_amz.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                  0
# discounted_price              0
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %%
df_flk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
df_flk.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
#finding total null values in each column of Flipkart Dataset
df_flk.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                 78
# discounted_price             78
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %% [markdown]
# ### Since there are 78 null values in retail_price and discounted_price columns, it is better to drop the rows having null values for these columns

# %%
df_flk= df_flk[-df_flk.retail_price.isnull()]

# %%
#Check mull values after removing the rows with null values
df_flk.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                  0
# discounted_price              0
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5851
# product_specifications       12
# dtype: int64

# %%
#installing fuzzymatcher#
pip install fuzzymatcher
# Out:
# ...
#
# ...

# %%
#importing fuzzymatcher
import fuzzymatcher

# %%
# fuzzy matching two dataframes on columns product name
df_final= fuzzymatcher.fuzzy_left_join(df_amz,df_flk,left_on='product_name',right_on='product_name')

# %%
df_final.head()
# Out:
#     best_match_score __id_left __id_right                      uniq_id_left  \
# 0           1.109848    0_left    0_right  c2d766ca982eca8304150849735ffef9
# 6           1.101432    1_left    1_right  7f7036a6d550aaa89d34c77bd39a5e48
# 10          0.511359    2_left    2_right  f449ec65dcbc041b6ae5e6a32717d01b
# 11          1.109848    3_left    0_right  0973b37acd0c664e3de26e97e5571454
# 17          1.485005    4_left    4_right  bc940ea42ee6bef5ac7cea3fb5cfbee7
#
#          crawl_timestamp_left  \
# 0   2016-03-25 22:59:23 +0000
# 6   2016-03-25 22:59:23 +0000
# 10  2016-03-25 22:59:23 +0000
# 11  2016-03-25 22:59:23 +0000
# 17  2016-03-25 22:59:23 +0000
#
#                                      product_url_left  \
# 0   http://www.flipkart.com/alisha-solid-women-s-c...
# 6   http://www.flipkart.com/fabhomedecor-fabric-do...
# 10  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 11  http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df_final.columns
# Out:
# Index(['best_match_score', '__id_left', '__id_right', 'uniq_id_left',
#        'crawl_timestamp_left', 'product_url_left', 'product_name_left',
#        'product_category_tree_left', 'pid_left', 'retail_price_left',
#        'discounted_price_left', 'image_left', 'is_FK_Advantage_product_left',
#        'description_left', 'product_rating_left', 'overall_rating_left',
#        'brand_left', 'product_specifications_left', 'uniq_id_right',
#        'crawl_timestamp_right', 'product_url_right', 'product_name_right',
#        'product_category_tree_right', 'pid_right', 'retail_price_right',
#        'discounted_price_right', 'image_right',
#        'is_FK_Advantage_product_right', 'description_right',
#        'product_rating_right', 'overall_rating_right', 'brand_right',
#        'product_specifications_right'],
#       dtype='object')

# %%
# Removing unwanted columns
df_final=df_final.drop(columns=['best_match_score','__id_left','__id_right','uniq_id_left','crawl_timestamp_left',
'product_url_left','product_category_tree_left', 'pid_left', 'image_left', 'is_FK_Advantage_product_left','description_left', 
'product_rating_left', 'overall_rating_left','brand_left', 'product_specifications_left', 'uniq_id_right',
'crawl_timestamp_right', 'product_url_right','product_category_tree_right', 'pid_right','image_right','is_FK_Advantage_product_right', 
'description_right','product_rating_right', 'overall_rating_right', 'brand_right','product_specifications_right'])

# %%
df_final.head()
# Out:
#                         product_name_left  retail_price_left  \
# 0     Alisha Solid Women's Cycling Shorts                982
# 6     FabHomeDecor Fabric Double Sofa Bed              32143
# 10                             AW Bellies                991
# 11    Alisha Solid Women's Cycling Shorts                694
# 17  Sicons All Purpose Arnica Dog Shampoo                208
#
#     discounted_price_left                     product_name_right  \
# 0                     438    Alisha Solid Women's Cycling Shorts
# 6                   29121    FabHomeDecor Fabric Double Sofa Bed
# 10                    551                             AW Bellies
# 11                    325    Alisha Solid Women's Cycling Shorts
# 17                    258  Sicons All Purpose Arnica Dog Shampoo
#
#     retail_price_right  discounted_price_right
# 0                999.0                   379.0
# 6              32157.0                 22646.0
# 10               999.0                   499.0
# ...

# %%
#Transferring dataframe to csv
df_final.to_csv(r"Amz_Flk_Final.csv")
